# %% [markdown]
# ## импортируем библиотеку

# %%
import pandas

# %% [markdown]
# ## подключаем csv.файл

# %%
df = pandas.read_csv("./kc_house_data.csv", encoding="latin-1")

# %% [markdown]
# ## смотрим данные в файле

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ## смотрим типы данных в таблице по столбцам

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ## уточним количество строк
# #### (ну, так.... для доп.информации)

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# ## проверим наличие нулевых строк

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ## смотрим, что по недвижимости
# #### видим, что большинство квартир стоит около 645000$ (75%), имеют в своём составе 4 комнаты, 2 ванных комнаты, чаще всего это 2 этаж в доме, год постройки 1997. Квадратуру не берём, т.к. мы видим жилую площадь в доме (а это, как правило, многоквартирные дома)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include="object")
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# ## посмотрим минимальную и максимальную цены за недвижимость

# %%
df.price.min()
# Out:
# 75000.0

# %%
df.price.max()
# Out:
# 7700000.0

# %%
df.price.describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# ## средняя жилая площадь 2550
# #### (это около 20% от общей площади)

# %%
df.sqft_living.describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %% [markdown]
# ## средняя НЕ жилая площадь составляет 10688

# %%
df.sqft_lot.describe()
# Out:
# count    2.161300e+04
# mean     1.510697e+04
# std      4.142051e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068800e+04
# max      1.651359e+06
# Name: sqft_lot, dtype: float64

# %% [markdown]
# ## определим самый дорогой дом

# %%
df[df.price == df.price.max()]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6        8.0
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %% [markdown]
# ## и самый дешёвый

# %%
df[df.price == df.price.min()]
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149  3421079032  20150217T000000  75000.0         1        0.0          670
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149     43377     1.0           0     0  ...      3         670
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149              0      1966             0    98022  47.2638 -121.906
#
#       sqft_living15  sqft_lot15
# 1149           1160       42882
#
# [1 rows x 21 columns]

# %% [markdown]
# ## определим самый старый и самый молодой дом

# %%
df.yr_built.min(), df.yr_built.max()
# Out:
# (1900, 2015)

# %% [markdown]
# ## определим среднюю стоимость домой с 2-мя спальнями
# #### и это около 401000$

# %%
df.groupby('bedrooms').mean()
# Out:
#                     id         price  bathrooms  sqft_living      sqft_lot  \
# bedrooms
# 0         4.632838e+09  4.095038e+05   0.826923  1707.846154  24141.307692
# 1         4.143251e+09  3.176429e+05   1.066583   884.613065  16285.673367
# 2         4.636499e+09  4.013727e+05   1.401721  1239.752899  12096.726087
# 3         4.535884e+09  4.662321e+05   1.968394  1805.837235  14414.790208
# 4         4.658470e+09  6.354195e+05   2.436428  2554.649666  16720.793374
# 5         4.517188e+09  7.865998e+05   2.778576  3047.545284  16769.022486
# 6         4.391720e+09  8.255206e+05   3.068015  3284.341912  18586.930147
# 7         4.027151e+09  9.511847e+05   3.651316  3974.210526  20840.552632
# 8         4.684170e+09  1.105077e+06   3.557692  3800.000000   8971.615385
# 9         5.465659e+09  8.939998e+05   4.416667  3775.000000   5480.000000
# 10        5.001934e+09  8.193333e+05   3.416667  3706.666667   8859.666667
# ...

# %% [markdown]
# ## офигеть, конечно, от 33-х спального дома))
# ## но видим, что бОльшая часть домой - это дома с 3-мя и 4-мя спальнями

# %%
df.groupby('bedrooms').count()['id']
# Out:
# bedrooms
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: id, dtype: int64

# %% [markdown]
# ## десятка самых дорогих домов))

# %%
df.sort_values(["price"],ascending=False).iloc[0:10]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %% [markdown]
# ## Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df.price > 600000]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 15     9297300055  20150124T000000   650000.0         4       3.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# ...           ...              ...        ...       ...        ...
# 21597   191100405  20150421T000000  1575000.0         4       3.25
# 21599  7202300110  20140915T000000   810000.0         4       3.00
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3             1960      5000     1.0           0     0  ...      7
# ...

# %% [markdown]
# ## а теперь посмотрим состояние домов
# #### ну, собственно, не все так безоблачно. Состояние домов ниже среднего (3,4 по 5-балльной)

# %%
df.groupby('condition').count()['id']
# Out:
# condition
# 1       30
# 2      172
# 3    14031
# 4     5679
# 5     1701
# Name: id, dtype: int64

# %%
df.condition.mean()
# Out:
# 3.4094295100171195

# %% [markdown]
# ## Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df[
    (df['sqft_basement'] == 0) &
    (df['price'] <= 150000) &
    (df['floors'] == 2)
]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 11255  1843200350  20140722T000000  150000.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 11255         1360      1934     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# ...

# %% [markdown]
# ## Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?
#
# около 2.2 млн.$

# %%
df[
    (df['waterfront'] == 1) |
    (df['view'] == 1) &
    (df['condition'] == 5) &
    (df['yr_built'] >= 1980)
].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  1.630000e+02  1.630000e+02  163.000000  163.000000    163.000000
# mean   4.490512e+09  1.661876e+06    3.300613    2.677914   3173.687117
# std    2.873261e+09  1.120372e+06    1.078035    1.092456   1606.025093
# min    1.210290e+08  2.850000e+05    1.000000    0.750000    440.000000
# 25%    2.013802e+09  7.600000e+05    3.000000    2.000000   2060.000000
# 50%    3.761100e+09  1.400000e+06    3.000000    2.500000   2850.000000
# 75%    7.377700e+09  2.215000e+06    4.000000    3.250000   3905.000000
# max    9.808701e+09  7.062500e+06    6.000000    6.750000  10040.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     163.000000  163.000000       163.0  163.000000  163.000000
# mean    25371.828221    1.641104         1.0    3.766871    3.533742
# std     42944.334119    0.554191         0.0    0.561859    0.739388
# ...

# %% [markdown]
# ## Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?
#
# 68 вариантов

# %%
df[
    (df['view'] == 1) &
    (df['sqft_basement'] != 0) &
    (df['bathrooms'] >= 3)
]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 282    7424700045  20150513T000000  2050000.0         5       3.00
# 556    5486800070  20140620T000000  1950000.0         7       3.50
# 779    1954700695  20140612T000000  2250000.0         5       4.25
# 902    2296500136  20140509T000000   839900.0         4       3.50
# 1161   7533800295  20140819T000000  1750000.0         4       3.25
# ...           ...              ...        ...       ...        ...
# 20535  1370800515  20141030T000000  2950000.0         4       4.25
# 20676   629890070  20140515T000000   828950.0         4       3.50
# 20729  3758900023  20140521T000000  1130000.0         4       3.25
# 20921  3864000120  20150408T000000  1175000.0         4       3.25
# 21310  2154970020  20140703T000000  2351960.0         4       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 282           3830      8480     2.0           0     1  ...      9
# ...
